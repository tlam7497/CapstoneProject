# %%
import sys
# !{sys.executable} -m pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Using cached https://files.pythonhosted.org/packages/44/a3/1218a3b5651dbcba1699101c84e5c84c36cbba360d9dbf29f2ff18482982/vaderSentiment-3.3.1-py2.py3-none-any.whl
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.1

# %%
import sys
# !{sys.executable} -m pip install nltk
# Out:
# Collecting nltk
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from nltk) (4.32.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from nltk) (7.0)
# Collecting regex (from nltk)
#   Using cached https://files.pythonhosted.org/packages/0f/fa/a9e3ad47c189969e3233031187b323fe20005fee4bfc8edcb24f8ffbe540/regex-2020.4.4-cp37-cp37m-manylinux2010_x86_64.whl
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from nltk) (0.13.2)
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.5 regex-2020.4.4

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from os import path
from PIL import Image
#from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter
import matplotlib.pyplot as plt
from matplotlib import rcParams
import multiprocessing as mp
import nltk
from nltk.corpus import stopwords
from nltk import PorterStemmer
from nltk import word_tokenize
from nltk.util import ngrams
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#% matplotlib inline

# %%
filename = ['sentiment_gr_category/sentiment_gr_category_{}.tsv'.format(k) for k in range(1,101)]
for file in filename:
    with open(file, 'r') as f:
        next(f)
        with open('sentiment_gr_positive.tsv','a') as p:
            with open('sentiment_gr_negative.tsv','a') as n:
                with open('sentiment_gr_neutral.tsv','a') as neu:
                    for i,line in enumerate(f):
                        text = line.strip().split('\t')
                        cleaned_text = text[2]
                        review_category = text[4]
                        overall = text[0]
                        if review_category == 'positive':
                            p.write(overall + '\t' + cleaned_text + '\n' )
                        elif review_category == 'negative':
                            n.write(overall + '\t' + cleaned_text + '\n' )
                        elif review_category == 'neutral':
                            neu.write(overall +'\t'+ cleaned_text + '\n' )

# %%
#from matplotlib.ticker import FuncFormatter
fig, ax = plt.subplots()
#formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
#ax.yaxis.set_major_formatter(formatter)
def count(filename):
    count = 0
    with open(filename,'r') as f:
        for line in f:
            count += 1
    return count
num_positive = count('sentiment_gr_positive.tsv')
num_negative = count('sentiment_gr_negative.tsv')
num_neutral = count('sentiment_gr_neutral.tsv')
objects = ('Positive', 'Negative', 'Neutral')
y_pos = np.arange(len(objects))
performance = [num_positive, num_negative, num_neutral]

rects1 = plt.bar(y_pos, performance, align='center', alpha=0.5)
for rect in rects1:
    height = rect.get_height()
    percent = (height/(num_positive+num_negative+num_neutral))*100
    ax.text(rect.get_x() + rect.get_width()/2., 1*height,
            '%.1f' % percent + "%", ha='center', va='bottom')
plt.xticks(y_pos, objects)
plt.ylabel('Count')
plt.xlabel('Review_category')
plt.title('Goodreads Sentiment')
plt.show()

# %%
num_positive
# Out:
# 707418

# %%
num_negative
# Out:
# 152562

# %%
num_neutral
# Out:
# 46758

# %% [markdown]
# # ----------------------------------------------------------

# %%
# Split the sentiment_gr_positive.tsv file 
import os

n = 707418 # number of reviews in the file
N = 40  # spliting to 20 files
k = 0

n_per_file = int(n // N) + 1

with open('sentiment_gr_positive.tsv', 'r') as f:
    next(f)
    g = None
    for i, line in enumerate(f):
        if i % n_per_file == 0:
            k = k + 1
            if not g == None:
                g.close()
            g = open('sentiment_gr_positive/sentiment_gr_positive_{}.tsv'.format(k), 'w')
            g.write("cleaned_text_positive\n")
        g.write("{}".format(line))
    g.close()

# %%
# Split the sentiment_gr_negative.tsv file 
import os

n = 152562 # number of reviews in the file
N = 20  # spliting to 100 files
k = 0

n_per_file = int(n // N) + 1

with open('sentiment_gr_negative.tsv', 'r') as f:
    next(f)
    g = None
    for i, line in enumerate(f):
        if i % n_per_file == 0:
            k = k + 1
            if not g == None:
                g.close()
            g = open('sentiment_gr_negative/sentiment_gr_negative_{}.tsv'.format(k), 'w')
            g.write("cleaned_text_negative\n")
        g.write("{}".format(line))
    g.close()

# %%
def graph(category, ngram, data):
    rcParams['font.family'] = 'sans-serif'
    rcParams['font.sans-serif'] = ['DejaVu Sans']
    fig, ax = plt.subplots(figsize=(15, 12))
    #rcParams['figure.figsize'] = 15,12
    sns.barplot(y='words',x='freq',data=data,color= 'cyan')
    plt.ylabel('Words', size = 15)
    plt.xlabel('Frequency', size = 15)
    title = 'Goodreads ' + category + 'Review ' + ngram + 'Top 50'
    plt.title(title, size = 20, weight = 'bold')
    #plt.xlim([0,900000])
    #ax.tick_params(labelsize = 10)

    #xticks = [100000,200000,300000,400000,500000,600000,700000,800000,900000]
    #replace_x_ticks = ['100k','200k','300k','400k','500k','600k', '700k', '800k']
    #plt.xticks(xticks, replace_x_ticks)

# %% [markdown]
# # -------------------------------------------------------
# # Unigram

# %%
positive = pd.read_csv('sentiment_gr_positive_unigram.csv')

# %%
graph('Positive ', 'Unigrams ', positive)

# %%
negative = pd.read_csv('sentiment_gr_negative_unigram.csv')

# %%
graph('Negative ', 'Unigrams ', negative)

# %%
positive_bigram= pd.read_csv('sentiment_gr_positive_bigram.csv')

# %%
positive_bigram
# Out:
#                       words   freq
# 0            ('but', 'not')  80135
# 1          ('read', 'book')  65651
# 2                ('*', '*')  54247
# 3          ('could', 'not')  51025
# 4           ('book', 'not')  45485
# 5          ('love', 'book')  38054
# 6           ('book', 'but')  35780
# 7           ('not', 'know')  35407
# 8     ('main', 'character')  35291
# 9         ('not', 'really')  32306
# 10         ('book', 'read')  31842
# 11         ('feel', 'like')  29032
# 12          ('not', 'like')  28388
# 13       ('even', 'though')  26497
# 14        ('first', 'book')  25824
# 15      ('really', 'enjoy')  25227
# 16         ('felt', 'like')  24935
# 17        ('enjoy', 'book')  24705
# 18         ('like', 'book')  24008
# 19         ('would', 'not')  23985
# 20          ('not', 'wait')  23644
# 21           ('not', 'get')  23274
# 22          ('not', 'want')  22927
# 23          ('but', 'also')  22538
# 24         ('but', 'still')  22165
# 25          ('not', 'read')  21823
# 26       ('book', 'series')  20852
# 27         ('not', 'think')  20735
# 28      ('look', 'forward')  20066
# 29          ('not', 'sure')  19651
# 30       ('really', 'like')  19137
# 31          ('not', 'even')  18543
# 32         ('next', 'book')  17341
# 33        ('well', 'write')  16858
# 34  ('highly', 'recommend')  16700
# 35        ('love', 'story')  16672
# 36         ('good', 'book')  16622
# 37       ('book', 'really')  15427
# 38          ('read', 'but')  15296
# 39       ('best', 'friend')  15226
# 40          ('not', 'much')  15138
# 41    ('recommend', 'book')  14497
# 42        ('great', 'book')  14454
# 43         ('book', 'like')  14155
# 44        ('would', 'like')  13965
# 45         ('story', 'not')  13898
# 46         ('seem', 'like')  13881
# 47          ('book', 'one')  13807
# 48          ('fun', 'read')  13574
# 49          ('year', 'old')  13443

# %%
graph('Positive ', 'Bigrams ', positive_bigram)

# %%
negative_bigram= pd.read_csv('sentiment_gr_negative_bigram.csv')

# %%
graph('Negative ', 'Bigrams ', negative_bigram)

# %% [markdown]
# # -------------------------------------------
# ## TRIGRAM

# %%
positive_trigram = pd.read_csv('sentiment_gr_positive_trigram.csv')

# %%
positive_trigram = positive_trigram[5:55]

# %%
positive_trigram['words']=positive_trigram['words'].astype(str).apply(lambda st: st[st.find("(")+1:st.find(")")]).str.replace('\'','').str.replace(',','_')
positive_trigram
# Out:
#                            words   freq
# 5                could_ not_ put  10226
# 6            really_ enjoy_ book   7573
# 7                not_ wait_ read   6859
# 8            look_ forward_ read   6294
# 9                 not_ help_ but   6294
# 10                book_ but_ not   4572
# 11      exchange_ honest_ review   4411
# 12               but_ could_ not   4280
# 13               could_ not_ get   4259
# 14              book_ ever_ read   4008
# 15              read_ next_ book   3540
# 16       highly_ recommend_ book   3471
# 17              but_ not_ really   3386
# 18                not_ wait_ see   3267
# 19               not_ read_ book   3209
# 20              could_ not_ help   3185
# 21               not_ feel_ like   3087
# 22            next_ book_ series   3081
# 23              book_ could_ not   3045
# 24             very_ well_ write   3022
# 25           first_ book_ series   3010
# 26        would_ recommend_ book   2962
# 27            really_ like_ book   2907
# 28               one_ best_ book   2868
# 29             even_ though_ not   2813
# 30             first_ half_ book   2781
# 31       recommend_ book_ anyone   2761
# 32               not_ get_ wrong   2720
# 33               not_ like_ book   2660
# 34                not_ put_ book   2645
# 35               not_ wait_ next   2643
# 36           look_ forward_ next   2637
# 37              could_ not_ stop   2591
# 38               read_ book_ not   2549
# 39              give_ book_ star   2533
# 40              best_ book_ read   2453
# 41              love_ love_ love   2406
# 42               read_ next_ one   2386
# 43               but_ not_ think   2349
# 44                read_ but_ not   2345
# 45           one_ favorite_ book   2236
# 46              make_ feel_ like   2158
# 47               not_ even_ know   2152
# 48                but_ not_ much   2076
# 49              wait_ read_ next   2071
# 50             read_ first_ book   2047
# 51        absolutely_ love_ book   2038
# 52              could_ not_ wait   2022
# 53  would_ definitely_ recommend   2009
# 54             first_ book_ read   1981

# %%
graph('Positive ', 'Trigrams ', positive_trigram)

# %%
negative_trigram = pd.read_csv('sentiment_gr_negative_trigram.csv')
negative_trigram
# Out:
#                             words  freq
# 0                 ('*', '*', '*')  4769
# 1           ('*', '*', 'spoiler')  3832
# 2       ('spoiler', 'alert', '*')  3690
# 3       ('*', 'spoiler', 'alert')  3685
# 4             ('alert', '*', '*')  3653
# 5         ('could', 'not', 'put')  2083
# 6         ('could', 'not', 'get')  1650
# 7         ('but', 'could', 'not')  1440
# 8          ('book', 'but', 'not')  1428
# 9          ('not', 'help', 'but')  1412
# 10        ('not', 'like', 'book')  1168
# 11         ('world', 'war', 'ii')  1034
# 12       ('book', 'ever', 'read')   942
# 13       ('but', 'not', 'really')   889
# 14  ('would', 'not', 'recommend')   813
# 15        ('not', 'feel', 'like')   781
# 16        ('not', 'read', 'book')   771
# 17    ('look', 'forward', 'read')   770
# 18       ('could', 'not', 'help')   748
# 19         ('read', 'but', 'not')   712
# 20       ('book', 'could', 'not')   692
# 21      ('first', 'half', 'book')   672
# 22         ('but', 'not', 'like')   647
# 23      ('not', 'really', 'like')   626
# 24      ('really', 'not', 'like')   611
# 25       ('not', 'make', 'sense')   606
# 26        ('but', 'not', 'think')   598
# 27     ('could', 'not', 'finish')   597
# 28      ('not', 'really', 'care')   596
# 29        ('not', 'even', 'know')   587
# 30        ('read', 'book', 'not')   582
# 31         ('good', 'but', 'not')   581
# 32    ('really', 'enjoy', 'book')   575
# 33        ('like', 'book', 'but')   566
# 34        ('but', 'not', 'great')   547
# 35    ('first', 'book', 'series')   545
# 36       ('read', 'next', 'book')   543
# 37           ('[', 'return', ']')   543
# 38      ('not', 'finish', 'book')   532
# 39       ('give', 'book', 'star')   531
# 40         ('but', 'not', 'sure')   527
# 41         ('not', 'put', 'book')   526
# 42         ('but', 'not', 'good')   524
# 43        ('not', 'wait', 'read')   521
# 44      ('even', 'though', 'not')   494
# 45      ('very', 'well', 'write')   491
# 46   ('not', 'recommend', 'book')   479
# 47         ('but', 'not', 'love')   458
# 48        ('make', 'no', 'sense')   454
# 49       ('not', 'enjoy', 'book')   449
# 50         ('but', 'not', 'know')   449
# 51       ('but', 'really', 'not')   435
# 52        ('but', 'would', 'not')   430
# 53        ('story', 'but', 'not')   426
# 54        ('not', 'get', 'wrong')   423
# 55          ('world', 'war', 'z')   420
# 56         ('but', 'not', 'much')   410
# 57       ('want', 'like', 'book')   408
# 58       ('could', 'not', 'stop')   406
# 59       ('could', 'not', 'even')   403

# %%
negative_trigram = negative_trigram.drop(negative_trigram.index[37])
negative_trigram = negative_trigram[5:55]

# %%
negative_trigram['words']=negative_trigram['words'].astype(str).apply(lambda st: st[st.find("(")+1:st.find(")")]).str.replace('\'','').str.replace(',','_')
negative_trigram
# Out:
#                     words  freq
# 5         could_ not_ put  2083
# 6         could_ not_ get  1650
# 7         but_ could_ not  1440
# 8          book_ but_ not  1428
# 9          not_ help_ but  1412
# 10        not_ like_ book  1168
# 11         world_ war_ ii  1034
# 12       book_ ever_ read   942
# 13       but_ not_ really   889
# 14  would_ not_ recommend   813
# 15        not_ feel_ like   781
# 16        not_ read_ book   771
# 17    look_ forward_ read   770
# 18       could_ not_ help   748
# 19         read_ but_ not   712
# 20       book_ could_ not   692
# 21      first_ half_ book   672
# 22         but_ not_ like   647
# 23      not_ really_ like   626
# 24      really_ not_ like   611
# 25       not_ make_ sense   606
# 26        but_ not_ think   598
# 27     could_ not_ finish   597
# 28      not_ really_ care   596
# 29        not_ even_ know   587
# 30        read_ book_ not   582
# 31         good_ but_ not   581
# 32    really_ enjoy_ book   575
# 33        like_ book_ but   566
# 34        but_ not_ great   547
# 35    first_ book_ series   545
# 36       read_ next_ book   543
# 38      not_ finish_ book   532
# 39       give_ book_ star   531
# 40         but_ not_ sure   527
# 41         not_ put_ book   526
# 42         but_ not_ good   524
# 43        not_ wait_ read   521
# 44      even_ though_ not   494
# 45      very_ well_ write   491
# 46   not_ recommend_ book   479
# 47         but_ not_ love   458
# 48        make_ no_ sense   454
# 49       not_ enjoy_ book   449
# 50         but_ not_ know   449
# 51       but_ really_ not   435
# 52        but_ would_ not   430
# 53        story_ but_ not   426
# 54        not_ get_ wrong   423
# 55          world_ war_ z   420

# %%
graph('Negative ', 'Trigrams ', negative_trigram)
