# %%
import pandas as pd
import numpy as np
import sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:T7u4L9a7m@localhost/Project')

# %% [markdown]
# # Goodreads Reviews

# %%
gr = pd.read_csv('goodreads_official.csv')
gr
# Out:
#          book_id  overall    reviewTime        asin  \
# 0       22551730        4  Dec 14, 2016  0307408868
# 1       18176747        5  Dec 21, 2016  0062273205
# 2         137554        0  Mar 20, 2014  006073731X
# 3          40955        5  Dec 21, 2016  0071424911
# 4        9850443        3  Aug 05, 2012  0062041266
# ...          ...      ...           ...         ...
# 906871   4405141        3  Aug 19, 2014  0061698954
# 906872   4405141        5  Apr 15, 2013  0061698954
# 906873   4405141        5  Jul 28, 2015  0061698954
# 906874   4405141        5  Mar 30, 2009  0061698954
# 906875   4405141        4  Aug 09, 2015  0061698954
#
#                                                reviewText
# 0       Another hard to put down nonfiction book from ...
# 1       I haven't read many (any?) books that are writ...
# 2                                Sacca and Nate recommend
# 3       A truly inspirational book by a truly inspirat...
# ...

# %%
len(np.unique(gr.asin))
# Out:
# 37233

# %%
gr.isnull().sum()
# Out:
# book_id       0
# overall       0
# reviewTime    0
# asin          0
# reviewText    0
# dtype: int64

# %%
gr.describe()
# Out:
#             book_id        overall
# count  9.068760e+05  906876.000000
# mean   8.419679e+06       3.669388
# std    8.535071e+06       1.248909
# min    5.900000e+01       0.000000
# 25%    3.739150e+05       3.000000
# 50%    6.631944e+06       4.000000
# 75%    1.333118e+07       5.000000
# max    3.638104e+07       5.000000

# %%
gr.to_sql('goodreads', con=engine, if_exists='replace', index=False)

# %% [markdown]
# ### Official Goodreads Dataset

# %%
gr = pd.read_csv('goodreads_cleaned_official.tsv', sep = '\t+', header=0)
# Out:
# C:\Users\Tu Lam\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
gr
# Out:
#         overall     reviewTime        asin  count_before  count_after  \
# 0             4  "Dec 14 2016"  0307408868           462          206
# 1             5  "Dec 21 2016"  0062273205          1328          619
# 2             0  "Mar 20 2014"  006073731X             4            3
# 3             5  "Dec 21 2016"  0071424911           943          397
# 4             3  "Aug 05 2012"  0062041266           347          152
# ...         ...            ...         ...           ...          ...
# 906871        3  "Aug 19 2014"  0061698954            32           11
# 906872        5  "Apr 15 2013"  0061698954            20           10
# 906873        5  "Jul 28 2015"  0061698954            14            8
# 906874        5  "Mar 30 2009"  0061698954            13            6
# 906875        4  "Aug 09 2015"  0061698954            17           10
#
#                                                reviewText  \
# 0       "Another hard to put down nonfiction book from...
# ...

# %%
gr.to_sql('goodreads', con=engine, if_exists='replace', index=False)

# %% [markdown]
# # Goodreads Metadata

# %%
gr_metadata = pd.read_csv('goodreads_metadata.csv')
gr_metadata
# Out:
#              asin  ratings_count  reviews_count  text_reviews_count  \
# 0      000100039X         186297         163625                5535
# 1      0001053655             16             33                   6
# 2      0001061240             10             22                   2
# 3      000161102X             33             74                   4
# 4      0001711296            604           1319                  48
# ...           ...            ...            ...                 ...
# 37228  0312953240             75            178                   8
# 37229  0312955138             27             75                   3
# 37230  0312955154             52             94                   5
# 37231  0312956878             57            189                   3
# 37232  0312956959             29             81                   6
#
#        total_ratings_count  total_reviews_count  total_text_reviews_count  \
# 0                   220088               196528                      8847
# ...

# %% [markdown]
# ### Books Metadata

# %%
book_metadata = pd.read_csv('book_metadata.csv')
book_metadata
# Out:
#         book_id  publication_year  publication_month  publication_day  \
# 0        780911            2002.0                9.0             16.0
# 1        926667            1964.0                3.0             18.0
# 2      18498572            2014.0                5.0              6.0
# 3        268464            2007.0                5.0             29.0
# 4        598199            2001.0                2.0             22.0
# ...         ...               ...                ...              ...
# 37234   5582304            2009.0                6.0              1.0
# 37235   3106983            2008.0                3.0              6.0
# 37236     11873            2004.0                7.0              1.0
# 37237    823091            1988.0                1.0              1.0
# 37238  20663470            2014.0                7.0              8.0
#
#                                publisher  \
# 0              Houghton Mifflin Harcourt
# ...

# %%
books_metadata_cleaned = pd.read_csv('books_metadata_cleaned.csv')
books_metadata_cleaned
# Out:
#         book_id  publication_year  publication_month  publication_day  \
# 0        780911            2002.0                9.0             16.0
# 1        926667            1964.0                3.0             18.0
# 2      18498572            2014.0                5.0              6.0
# 3        268464            2007.0                5.0             29.0
# 4        598199            2001.0                2.0             22.0
# ...         ...               ...                ...              ...
# 37233   5582304            2009.0                6.0              1.0
# 37234   3106983            2008.0                3.0              6.0
# 37235     11873            2004.0                7.0              1.0
# 37236    823091            1988.0                1.0              1.0
# 37237  20663470            2014.0                7.0              8.0
#
#                                publisher  \
# 0              Houghton Mifflin Harcourt
# ...

# %%
duplicateRowsDF = gr_description[gr_description.duplicated(['asin'])]
duplicateRowsDF
# Out:
#         book_id        asin  \
# 5591   12924261  0312546343
# 5746   16286441  031254507X
# 13135    880185  0140106995
# 17308   9707946  0028604199
# 19511     17267  0006280560
# 34859  13009002  0141180358
#
#                                              description  \
# 5591   From the writer of the cult sensation John Die...
# 5746   Jace's return to Kansas is an instant reminder...
# 13135  An autobiography of John James Todd, a Scotsma...
# 17308                                                NaN
# 19511  In "The Great Divorce, " C.S. Lewis's classic ...
# 34859  Since the original prewar translation there ha...
#
#                                      cleaned_description
# 5591   writer cult sensation john die incomes another...
# 5746   face return kansa instant reminder place like ...
# 13135  autobiography john james tell scotsman born on...
# 17308                                                NaN
# 19511  great divorce c lewis classic vision afterworl...
# ...

# %%
for book in duplicateRowsDF.asin:
    print(book_metadata[book_metadata['asin'] == book])
# Out:
#        book_id  publication_year  publication_month  publication_day  \
# 5590  16060614            2012.0               10.0              2.0
# 5591  12924261            2012.0               10.0              2.0
#
#                publisher                                        description  \
# 5590  Thomas Dunne Books  Fan favorite David Wong takes readers to a who...
# 5591  St. Martin's Press  From the writer of the cult sensation John Die...
#
#       num_pages          format  \
# 5590      417.0  Kindle Edition
# 5591      406.0       Hardcover
#
#                                                  genres        asin
# 5590  {'fiction': 405, 'fantasy, paranormal': 244, '...  0312546343
# 5591  {'fiction': 405, 'fantasy, paranormal': 244, '...  0312546343
#        book_id  publication_year  publication_month  publication_day  \
# 5745  13539454            2012.0               11.0             27.0
# 5746  16286441            2012.0               11.0             27.0
#
# ...

# %% [markdown]
# ### Goodreads Description

# %%
gr_description = pd.read_csv('goodreads_description.csv')
gr_description
# Out:
#         book_id        asin  \
# 0        780911  015100692X
# 1        926667  0156182890
# 2      18498572  0062310194
# 3        268464  0061198722
# 4        598199  0195145852
# ...         ...         ...
# 37234   5582304  0306815869
# 37235   3106983  009952399X
# 37236     11873  0099285568
# 37237    823091  0153117362
# 37238  20663470  0310744806
#
#                                              description  \
# 0      "Michel Faber leads us back to 1870s London, w...
# 1      A modern verse play about the search for meani...
# 2      The dramatic, first-hand account of the histor...
# 3      Celebrity journalist Amelia Stone is the quint...
# 4      Throughout African-American history, religion ...
# ...                                                  ...
# 37234  Drawing on intimate recollections from friends...
# 37235  The Story of a Childhood and The Story of a Re...
# 37236  WINNER OF THE PULITZER PRIZE\nIn 1831 Nat Turn...
# ...

# %% [markdown]
# ### Merge Metadata Dataframes

# %%
book_metadata.isnull().sum()
# Out:
# book_id                 0
# publication_year     4284
# publication_month    5313
# publication_day      5575
# publisher            4344
# description          1748
# num_pages            4008
# format               4616
# genres                  0
# asin                    0
# dtype: int64

# %%
book_metadata.describe()
# Out:
#             book_id  publication_year  publication_month  publication_day  \
# count  3.723900e+04      32955.000000       31926.000000     31664.000000
# mean   7.281608e+06       2005.514489           6.355102        13.950227
# std    8.721178e+06          9.359460           3.345785        10.389918
# min    5.900000e+01       1900.000000           1.000000         1.000000
# 25%    5.720380e+05       2002.000000           4.000000         4.000000
# 50%    2.659586e+06       2008.000000           6.000000        13.000000
# 75%    1.203250e+07       2012.000000           9.000000        24.000000
# max    3.638104e+07       2018.000000          12.000000        31.000000
#
#           num_pages
# count  33231.000000
# mean     320.532725
# std      188.363295
# min        0.000000
# 25%      224.500000
# 50%      306.000000
# 75%      384.000000
# max     5392.000000

# %%
# Manually delete duplicated asin
book_metadata = book_metadata.drop(book_metadata.index[34858])
book_metadata = book_metadata.drop(book_metadata.index[19511])
book_metadata = book_metadata.drop(book_metadata.index[17308])  
book_metadata = book_metadata.drop(book_metadata.index[13135]) 
book_metadata = book_metadata.drop(book_metadata.index[5746])  
book_metadata = book_metadata.drop(book_metadata.index[5590])  
book_metadata
# Out:
#         book_id  publication_year  publication_month  publication_day  \
# 0        780911            2002.0                9.0             16.0
# 1        926667            1964.0                3.0             18.0
# 2      18498572            2014.0                5.0              6.0
# 3        268464            2007.0                5.0             29.0
# 4        598199            2001.0                2.0             22.0
# ...         ...               ...                ...              ...
# 37234   5582304            2009.0                6.0              1.0
# 37235   3106983            2008.0                3.0              6.0
# 37236     11873            2004.0                7.0              1.0
# 37237    823091            1988.0                1.0              1.0
# 37238  20663470            2014.0                7.0              8.0
#
#                                publisher  \
# 0              Houghton Mifflin Harcourt
# ...

# %%
# Manually delete duplicated asin
gr_description = gr_description.drop(gr_description.index[34858])
gr_description = gr_description.drop(gr_description.index[19511])
gr_description = gr_description.drop(gr_description.index[17308])  
gr_description = gr_description.drop(gr_description.index[13135]) 
gr_description = gr_description.drop(gr_description.index[5746])  
gr_description = gr_description.drop(gr_description.index[5590])  
gr_description
# Out:
#         book_id        asin  \
# 0        780911  015100692X
# 1        926667  0156182890
# 2      18498572  0062310194
# 3        268464  0061198722
# 4        598199  0195145852
# ...         ...         ...
# 37234   5582304  0306815869
# 37235   3106983  009952399X
# 37236     11873  0099285568
# 37237    823091  0153117362
# 37238  20663470  0310744806
#
#                                              description  \
# 0      "Michel Faber leads us back to 1870s London, w...
# 1      A modern verse play about the search for meani...
# 2      The dramatic, first-hand account of the histor...
# 3      Celebrity journalist Amelia Stone is the quint...
# 4      Throughout African-American history, religion ...
# ...                                                  ...
# 37234  Drawing on intimate recollections from friends...
# 37235  The Story of a Childhood and The Story of a Re...
# 37236  WINNER OF THE PULITZER PRIZE\nIn 1831 Nat Turn...
# ...

# %%
gr_metadata = pd.merge(gr_metadata, book_metadata[['publication_year', 'publication_month', 'publication_day',
                                                  'publisher', 'num_pages', 'format', 'asin']], how='inner', on='asin')
gr_metadata
# Out:
#              asin  ratings_count  reviews_count  text_reviews_count  \
# 0      000100039X         186297         163625                5535
# 1      0001053655             16             33                   6
# 2      0001061240             10             22                   2
# 3      000161102X             33             74                   4
# 4      0001711296            604           1319                  48
# ...           ...            ...            ...                 ...
# 37228  0312953240             75            178                   8
# 37229  0312955138             27             75                   3
# 37230  0312955154             52             94                   5
# 37231  0312956878             57            189                   3
# 37232  0312956959             29             81                   6
#
#        total_ratings_count  total_reviews_count  total_text_reviews_count  \
# 0                   220088               196528                      8847
# ...

# %%
gr_metadata = pd.merge(gr_metadata, gr_description[['asin', 'description', 'cleaned_description']], how='inner', on='asin')
gr_metadata
# Out:
#              asin  ratings_count  reviews_count  text_reviews_count  \
# 0      000100039X         186297         163625                5535
# 1      0001053655             16             33                   6
# 2      0001061240             10             22                   2
# 3      000161102X             33             74                   4
# 4      0001711296            604           1319                  48
# ...           ...            ...            ...                 ...
# 37228  0312953240             75            178                   8
# 37229  0312955138             27             75                   3
# 37230  0312955154             52             94                   5
# 37231  0312956878             57            189                   3
# 37232  0312956959             29             81                   6
#
#        total_ratings_count  total_reviews_count  total_text_reviews_count  \
# 0                   220088               196528                      8847
# ...

# %%
gr_metadata = gr_metadata[['asin', 'average_rating', 'ratings_count', 'reviews_count', 'text_reviews_count', 
                           'total_ratings_count', 'total_reviews_count', 'total_text_reviews_count', 'publication_year', 
                           'publication_month', 'publication_day', 'publisher', 'num_pages', 'format', 'description', 
                           'cleaned_description']]

# %%
gr_metadata
# Out:
#              asin  average_rating  ratings_count  reviews_count  \
# 0      000100039X            4.23         186297         163625
# 1      0001053655            4.08             16             33
# 2      0001061240            4.62             10             22
# 3      000161102X            3.86             33             74
# 4      0001711296            4.29            604           1319
# ...           ...             ...            ...            ...
# 37228  0312953240            3.80             75            178
# 37229  0312955138            3.38             27             75
# 37230  0312955154            3.36             52             94
# 37231  0312956878            3.78             57            189
# 37232  0312956959            3.27             29             81
#
#        text_reviews_count  total_ratings_count  total_reviews_count  \
# 0                    5535               220088               196528
# ...

# %%
gr_metadata.describe()
# Out:
#        average_rating  ratings_count  reviews_count  text_reviews_count  \
# count    37233.000000   3.723300e+04   3.723300e+04        37233.000000
# mean         3.873311   2.141833e+03   4.211693e+03          145.747267
# std          0.306148   2.213376e+04   2.996176e+04          974.148611
# min          2.320000   0.000000e+00   0.000000e+00            0.000000
# 25%          3.690000   5.900000e+01   1.500000e+02            9.000000
# 50%          3.890000   1.860000e+02   5.060000e+02           24.000000
# 75%          4.080000   6.900000e+02   1.797000e+03           75.000000
# max          5.000000   2.056193e+06   2.238009e+06        68752.000000
#
#        total_ratings_count  total_reviews_count  total_text_reviews_count  \
# count         3.723300e+04         3.723300e+04              37233.000000
# mean          1.147746e+04         1.963290e+04                614.953992
# std           8.537788e+04         1.153654e+05               3121.161743
# ...

# %%
gr_metadata.isnull().sum()
# Out:
# asin                           0
# average_rating                 0
# ratings_count                  0
# reviews_count                  0
# text_reviews_count             0
# total_ratings_count            0
# total_reviews_count            0
# total_text_reviews_count       0
# publication_year            4283
# publication_month           5311
# publication_day             5573
# publisher                   4343
# num_pages                   4007
# format                      4614
# description                 1747
# cleaned_description         1748
# dtype: int64

# %%
gr_metadata.to_csv('gr_metadata_to_crawl.csv', index=False)

# %%
gr_metadata.to_sql('goodreads_metadata', con=engine, if_exists='replace', index=False)

# %% [markdown]
# ### Books Metadata Final

# %%
gr_metadata = pd.read_csv('official_goodreads_metadata.csv')
gr_metadata
# Out:
#              asin  average_rating  ratings_count  reviews_count  \
# 0      000100039X            4.23         186297         163625
# 1      0001053655            4.08             16             33
# 2      0001061240            4.62             10             22
# 3      000161102X            3.86             33             74
# 4      0001711296            4.29            604           1319
# ...           ...             ...            ...            ...
# 37228  0312953240            3.80             75            178
# 37229  0312955138            3.38             27             75
# 37230  0312955154            3.36             52             94
# 37231  0312956878            3.78             57            189
# 37232  0312956959            3.27             29             81
#
#        text_reviews_count  total_ratings_count  total_reviews_count  \
# 0                    5535               220088               196528
# ...

# %%
gr_metadata.to_sql('goodreads_metadata', con=engine, if_exists='replace', index=False)

# %% [markdown]
# # Amazon Metadata

# %%
am_metadata = pd.read_csv('complete_amazon_metadata.csv')
am_metadata
# Out:
#        Unnamed: 0        asin  average  rating_count  text_reviews_count  \
# 0               0  0001713353     4.83            54                  54
# 1               1  0001061240     4.87            45                  45
# 2               2  0001711296     4.44           107                 107
# 3               3  0002007649     3.37            19                  19
# 4               4  0001716069     4.61            59                  59
# ...           ...         ...      ...           ...                 ...
# 37228       37228  0312943636     4.17            24                  24
# 37229       37229  0312953038     4.00            27                  27
# 37230       37230  0312955154     3.29            14                  14
# 37231       37231  0312956878     3.33            15                  15
# 37232       37232  0312947763     2.30            33                  33
#
#                                        genres       rank  verifiedTrue_count  \
# ...

# %%
am_metadata.to_sql('amazon_metadata', con=engine, if_exists='replace', index=False)

# %% [markdown]
# ### Official Amazon Metadata

# %%
am_metadata = pd.read_csv('official_amazon_metadata.csv')
am_metadata
# Out:
#              asin  average  rating_count  text_reviews_count  \
# 0      0001713353     4.83            54                  54
# 1      0001061240     4.87            45                  45
# 2      0001711296     4.44           107                 107
# 3      0002007649     3.37            19                  19
# 4      0001716069     4.61            59                  59
# ...           ...      ...           ...                 ...
# 37228  0312943636     4.17            24                  24
# 37229  0312953038     4.00            27                  27
# 37230  0312955154     3.29            14                  14
# 37231  0312956878     3.33            15                  15
# 37232  0312947763     2.30            33                  33
#
#                                        genres     rank  verifiedTrue_count  \
# 0       Childrens Books, Literature & Fiction  1461315                  36
# 1       Childrens Books, Literature & Fiction   321557                  30
# ...

# %%
am_metadata.to_sql('amazon_metadata', con=engine, if_exists='replace', index=False)
